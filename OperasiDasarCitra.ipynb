# %%
# Meng import library yg ada pada python
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2 

from skimage import data
from skimage.io import imread
from skimage.color import rgb2gray 
from skimage.util import invert

import numpy as np

# %%
#percobaan 1
# untuk memuat Gambar
astronautImage = data.astronaut()
cameraImage = data.camera()

 # Menyalin gambar dan mecropping gambar
astroCropped = astronautImage.copy()
astroCropped = astroCropped[0:256,64:320]

# Menyalin gambar dan mecropping gambar
cameraCropped = cameraImage.copy()
cameraCropped = cameraCropped[64:320,128:320]

# Membuat subplot dengan 2 baris dan 2 kolom dengan jarak 12
fig, axes = plt.subplots(2, 2, figsize = (12, 12))
ax = axes.ravel()

#menampilkan gambar dan title
ax[0].imshow(astronautImage)
ax[0].set_title("Citra Input 1")
ax[1].imshow(cameraImage, cmap='gray')
ax[1].set_title("Citra Input 2")
ax[2].imshow(astroCropped)
ax[2].set_title("Citra Output 1")
ax[3].imshow(cameraCropped, cmap='gray')
ax[3].set_title("Citra Output 2")

fig.tight_layout
plt.show()

# %%
# Import Library
import matplotlib.pyplot as plt
import cv2

from skimage import data
from skimage.io import imread
from skimage.color import rgb2gray
from skimage.util import invert
import numpy as np

# %%
# Membuat Gambar dan Mecropping Gambar
loadImage = imread(fname="gambar2.jpg")
loadImagecropped = loadImage.copy()
loadImagecropped = loadImagecropped[140:500,240:720]

# Membuat subplot dengan 2 baris dan 1 kolom dengan jarak 12
fig, axes = plt.subplots(1, 2, figsize = (10, 10))
ax = axes.ravel()

#Menampilkan Gambar dan Titlle
ax[0].imshow(loadImage)
ax[0].set_title("Citra Input 1")
ax[1].imshow(loadImagecropped)
ax[1].set_title("Citra Output 2")

fig.tight_layout
plt.show()

# %%
inv = invert(loadImagecropped)
print('Shape Input : ', loadImagecropped.shape)
print('Shape Output : ',inv.shape)

# Membuat subplot dengan 2 baris dan 2 kolom dengan jarak 12
fig, axes = plt.subplots(2, 2, figsize=(12, 12))
ax = axes.ravel()

ax[0].imshow(loadImagecropped)
ax[0].set_title("Citra Input")

ax[1].hist(loadImagecropped.ravel(), bins=256)
ax[1].set_title('Histogram Input')

ax[2].imshow(inv)
ax[2].set_title('Citra Output (Inverted Image)')

ax[3].hist(inv.ravel(), bins=256)
ax[3].set_title('Histogram Output')
# Out:
# Shape Input :  (360, 480, 3)
# Shape Output :  (360, 480, 3)
# Text(0.5, 1.0, 'Histogram Output')

# %%
loadImagecropped = cv2.cvtColor(loadImagecropped, cv2.COLOR_BGR2RGB)
img_crop_bright = cv2.add(loadImagecropped, 30)
plt.imshow(cv2.cvtColor(img_crop_bright, cv2.COLOR_BGR2RGB))
plt.title('Brightened Image +30')
plt.show()
# Histogram of brightened image
plt.hist(img_crop_bright.ravel(), bins=256, range=[0, 256])
plt.title('Histogram of Brightened Cropped Image')
plt.show()
